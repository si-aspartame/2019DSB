# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/convert-to-regression-with-tuning/__resultx__.html
# /kaggle/input/convert-to-regression-with-tuning/nn_model.w8.data-00000-of-00001
# /kaggle/input/convert-to-regression-with-tuning/custom.css
# /kaggle/input/convert-to-regression-with-tuning/__notebook__.ipynb
# /kaggle/input/convert-to-regression-with-tuning/nn_model.w8.index
# /kaggle/input/convert-to-regression-with-tuning/__results__.html
# /kaggle/input/convert-to-regression-with-tuning/__output__.json
# /kaggle/input/convert-to-regression-with-tuning/submission.csv
# /kaggle/input/convert-to-regression-with-tuning/checkpoint
# /kaggle/input/convert-to-regression-with-tuning/__results___files/__results___38_1.png
# /kaggle/input/convert-to-regression-with-tuning/__results___files/__results___45_2.png
# /kaggle/input/convert-to-regression-with-tuning/__results___files/__results___44_4.png
# /kaggle/input/convert-to-regression-with-tuning/__results___files/__results___48_2.png
# /kaggle/input/simple/reduce_train_from_test.csv
# /kaggle/input/simple/reduce_train.csv
# /kaggle/input/simple/__output__.json
# /kaggle/input/simple/submission.csv
# /kaggle/input/simple/reduce_test.csv
# /kaggle/input/data-science-bowl-data-minification/Strat_train_X.csv
# /kaggle/input/data-science-bowl-data-minification/Strat_test_X.csv
# /kaggle/input/data-science-bowl-data-minification/__resultx__.html
# /kaggle/input/data-science-bowl-data-minification/Groupk_test_X.csv
# /kaggle/input/data-science-bowl-data-minification/custom.css
# /kaggle/input/data-science-bowl-data-minification/__notebook__.ipynb
# /kaggle/input/data-science-bowl-data-minification/__results__.html
# /kaggle/input/data-science-bowl-data-minification/__output__.json
# /kaggle/input/data-science-bowl-data-minification/Groupk_train_X.csv
# /kaggle/input/data-science-bowl-data-minification/__results___files/__results___15_0.png
# /kaggle/input/data-science-bowl-data-minification/__results___files/__results___21_0.png
# /kaggle/input/data-science-bowl-data-minification/__results___files/__results___20_1.png
# /kaggle/input/data-science-bowl-data-minification/__results___files/__results___39_1.png
# /kaggle/input/data-science-bowl-data-minification/__results___files/__results___23_0.png
# /kaggle/input/data-science-bowl-data-minification/__results___files/__results___30_1.png
# /kaggle/input/data-science-bowl-data-minification/__results___files/__results___22_1.png
# /kaggle/input/convert-to-regression-bf75e3/__resultx__.html
# /kaggle/input/convert-to-regression-bf75e3/nn_model.w8.data-00000-of-00001
# /kaggle/input/convert-to-regression-bf75e3/custom.css
# /kaggle/input/convert-to-regression-bf75e3/__notebook__.ipynb
# /kaggle/input/convert-to-regression-bf75e3/nn_model.w8.index
# /kaggle/input/convert-to-regression-bf75e3/__results__.html
# /kaggle/input/convert-to-regression-bf75e3/__output__.json
# /kaggle/input/convert-to-regression-bf75e3/submission.csv
# /kaggle/input/convert-to-regression-bf75e3/checkpoint
# /kaggle/input/convert-to-regression-bf75e3/__results___files/__results___26_2.png
# /kaggle/input/convert-to-regression-bf75e3/__results___files/__results___22_4.png
# /kaggle/input/convert-to-regression-bf75e3/__results___files/__results___17_1.png
# /kaggle/input/data-science-bowl-2019/train.csv
# /kaggle/input/data-science-bowl-2019/train_labels.csv
# /kaggle/input/data-science-bowl-2019/specs.csv
# /kaggle/input/data-science-bowl-2019/test.csv
# /kaggle/input/data-science-bowl-2019/sample_submission.csv

# %%
submission_list = os.listdir('/kaggle/input')
print(submission_list)
# Out:
# ['convert-to-regression-with-tuning', 'simple', 'data-science-bowl-data-minification', 'convert-to-regression-bf75e3', 'data-science-bowl-2019']

# %%
csv_list=[ \
    'convert-to-regression-bf75e3/submission', \
    'convert-to-regression-with-tuning/submission', \
    'data-science-bowl-data-minification/Groupk_test_X', \
    'data-science-bowl-data-minification/Strat_test_X', \
    'simple/submission' \
    ]

# %%
path = '/kaggle/input/'
print('reading...')
csv_files=[]
for c in csv_list:
    print(c)
    df=pd.read_csv(path+'/'+c+'.csv')
    csv_files.append(df)
submit=pd.read_csv('../input/data-science-bowl-2019/sample_submission.csv')
# Out:
# reading...
# convert-to-regression-bf75e3/submission
# convert-to-regression-with-tuning/submission
# data-science-bowl-data-minification/Groupk_test_X
# data-science-bowl-data-minification/Strat_test_X
# simple/submission

# %%
print('blending...')
mrs=[]
for n, f in enumerate(csv_files):
    print(n)
    mrs.append(f['accuracy_group'])
name_and_mr_dic=dict(zip(csv_list, mrs))
all_meter_reading_df=pd.DataFrame(name_and_mr_dic)
submit['accuracy_group'] = all_meter_reading_df.median(axis=1)
# Out:
# blending...
# 0
# 1
# 2
# 3
# 4

# %%
print(submit['accuracy_group'][0], '|', \
        mrs[0][0], '|', \
        mrs[1][0], '|', \
        mrs[2][0], '|', \
        mrs[3][0], '|', \
        mrs[4][0] \
    )
# Out:
# 3 | 3 | 3 | 0 | 0 | 3

# %%
submit['accuracy_group'] = submit['accuracy_group'].astype(int)
print('writing...')
submit.to_csv("/kaggle/working/submission.csv", index=False)
print('done!')
# Out:
# writing...
# done!
